# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# 2023-08-26 09:10:13.736034: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-26 09:10:14.977664: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 23.5 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip install pdfminer.six
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 38.1 MB/s eta 0:00:00
# ...

# %%
# !pip install PyPDF2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# For Set of resumes in a folder

import os
from PyPDF2 import PdfReader

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as pdf_file:
        pdf_reader = PdfReader(pdf_file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

if __name__ == '__main__':
    pdf_folder = "/content/drive/MyDrive/Hackathon_Dataset/Resumes_pdf"
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            text = extract_text_from_pdf(pdf_path)
            print(f"Text extracted from {pdf_file}:\n{text}\n")
# Out:
# Text extracted from 36517781.pdf:
# LIGHTING FIELD ENGINEERING TECHNICIAN
# Summary
# Engineering Technician with an impressive blend of technical expertise and people skills. Committed to providing quality and consistent technical
# support.
# Highlights
# Excellent communication techniques
# AutoCAD expert
# Microsoft Excel, Project and Visio
# Advanced critical thinking
# Accomplishments
# AutoCad Software Utilization
#  Â
# Produced drawings and maintained, archived and retrieved CAD files and drawing documents for the completion of multiple commercial
# projects.
# Project Management
# Supervised project production efforts to ensure projects were completed to company standards, on time and within budget constraints.
# Experience
# Lighting Field Engineering Technician
#
# 10/2014
#
# to
# 01/2016
#
# Company Name
#
# City
#
# ,
# State
# Supports Tampa Electric Company's lighting system construction and maintenance projects.
# ...

# %%
# # For single Resume

# from pdfminer.high_level import extract_text

# def extract_text_from_pdf(pdf_path):
#     return extract_text(pdf_path)

# if __name__ == '__main__':
#     print(extract_text_from_pdf(r"/content/45987048.pdf"))

# %%
# For Set of resumes in a folder
# Exctracting Name from Resume

import pdfminer
import re

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as pdf_file:
        pdf_reader = PdfReader(pdf_file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def extract_name_from_resume(text):
    name = None

    # Use regex pattern to find a potential name
    pattern = r"(\b[A-Z][a-z]+\b)\s(\b[A-Z][a-z]+\b)"
    match = re.search(pattern, text)
    if match:
        name = match.group()

    return name

if __name__ == '__main__':
    pdf_folder = "/content/drive/MyDrive/Hackathon_Dataset/Resumes_pdf"
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            text = extract_text_from_pdf(pdf_path)
            name = extract_name_from_resume(text)

        if name:
            print("Name:", name)
        else:
            print("Name not found")
# Out:
# Name: Summary
# Engineering
# Name: Career Overview
# Name: Experience
# Director
# Name: Summary
# Seeking
# Name: Professional Summary
# Name: Professional Summary
# Name: Summary
# Applying
# Name: Experience
# Company
# Name: Summary
# Accomplished
# Name: Marilyn Hunter

# %%
# # For single Resume
# # Exctracting Name from Resume

# import pdfminer
# import re

# def extract_text_from_pdf(pdf_path):
#     return extract_text(pdf_path)

# def extract_name_from_resume(text):
#     name = None

#     # Use regex pattern to find a potential name
#     pattern = r"(\b[A-Z][a-z]+\b)\s(\b[A-Z][a-z]+\b)"
#     match = re.search(pattern, text)
#     if match:
#         name = match.group()

#     return name

# if __name__ == '__main__':
#     text = extract_text_from_pdf(r"/content/45987048.pdf")
#     name = extract_name_from_resume(text)

#     if name:
#         print("Name:", name)
#     else:
#         print("Name not found")
# Out:
# Name: Marilyn Hunter

# %%
# For Set of resumes in a folder
# Exctracting Contact Number from Resume

import pdfminer
import re

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as pdf_file:
        pdf_reader = PdfReader(pdf_file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def extract_contact_number_from_resume(text):
    contact_number = None

    # Use regex pattern to find a potential contact number
    pattern = r"\b(?:\+?\d{1,3}[-.\s]?)?\(?\d{3}\)?[-.\s]?\d{3}[-.\s]?\d{4}\b"
    match = re.search(pattern, text)
    if match:
        contact_number = match.group()

    return contact_number

if __name__ == '__main__':
    pdf_folder = "/content/drive/MyDrive/Hackathon_Dataset/Resumes_pdf"
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            text = extract_text_from_pdf(pdf_path)
            contact_number = extract_contact_number_from_resume(text)

        if contact_number:
            print("Contact Number:", contact_number)
        else:
            print("Contact Number not found")
# Out:
# Contact Number not found
# Contact Number not found
# Contact Number not found
# Contact Number not found
# Contact Number not found
# Contact Number not found
# Contact Number: 502-868-6764
# Contact Number not found
# Contact Number not found
# Contact Number not found

# %%
# # For single Resume
# # Exctract Contact Number

# def extract_text_from_pdf(pdf_path):
#     return extract_text(pdf_path)

# def extract_contact_number_from_resume(text):
#     contact_number = None

#     # Use regex pattern to find a potential contact number
#     pattern = r"\b(?:\+?\d{1,3}[-.\s]?)?\(?\d{3}\)?[-.\s]?\d{3}[-.\s]?\d{4}\b"
#     match = re.search(pattern, text)
#     if match:
#         contact_number = match.group()

#     return contact_number

# if __name__ == '__main__':
#     text = extract_text_from_pdf(r"/content/45987048.pdf")
#     contact_number = extract_contact_number_from_resume(text)

#     if contact_number:
#         print("Contact Number:", contact_number)
#     else:
#         print("Contact Number not found")
# Out:
# Contact Number not found

# %%
# For Set of resumes in a folder
# Exctracting Email Id from Resume

import pdfminer
import re

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as pdf_file:
        pdf_reader = PdfReader(pdf_file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def extract_email_from_resume(text):
    email = None

    # Use regex pattern to find a potential email address
    pattern = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
    match = re.search(pattern, text)
    if match:
        email = match.group()

    return email

if __name__ == '__main__':
    pdf_folder = "/content/drive/MyDrive/Hackathon_Dataset/Resumes_pdf"
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            text = extract_text_from_pdf(pdf_path)
            email = extract_email_from_resume(text)

        if email:
            print("Email:", email)
        else:
            print("Email not found")

# %%
# # For single Resume
# # Exctract Email Id

# def extract_text_from_pdf(pdf_path):
#     return extract_text(pdf_path)

# def extract_email_from_resume(text):
#     email = None

#     # Use regex pattern to find a potential email address
#     pattern = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
#     match = re.search(pattern, text)
#     if match:
#         email = match.group()

#     return email

# if __name__ == '__main__':
#     text = extract_text_from_pdf(r"/content/45987048.pdf")
#     email = extract_email_from_resume(text)

#     if email:
#         print("Email:", email)
#     else:
#         print("Email not found")
# Out:
# Email not found

# %%
# For Set of resumes in a folder
# Exctracting Skills from Resume

import pdfminer
import re

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as pdf_file:
        pdf_reader = PdfReader(pdf_file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def extract_skills_from_resume(text, skills_list):
    skills = []

    # Search for skills in the resume text
    for skill in skills_list:
        pattern = r"\b{}\b".format(re.escape(skill))
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            skills.append(skill)

    return skills

if __name__ == '__main__':
    pdf_folder = "/content/drive/MyDrive/Hackathon_Dataset/Resumes_pdf"
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            text = extract_text_from_pdf(pdf_path)
            # List of predefined skills
            skills_list = ['Python', 'Data Analysis', 'Machine Learning', 'Communication', 'Project Management', 'Deep Learning', 'SQL', 'Tableau']

            extracted_skills = extract_skills_from_resume(text, skills_list)

        if extracted_skills:
            print("Skills:", extracted_skills)
        else:
            print("No skills found")
# Out:
# Skills: ['Communication', 'Project Management']
# No skills found
# Skills: ['Communication']
# Skills: ['Communication']
# No skills found
# Skills: ['Communication']
# Skills: ['Communication']
# Skills: ['Communication']
# Skills: ['Communication']
# No skills found

# %%
# # For single Resume
# # Exctracting Skills

# def extract_text_from_pdf(pdf_path):
#     return extract_text(pdf_path)

# def extract_skills_from_resume(text, skills_list):
#     skills = []

#     # Search for skills in the resume text
#     for skill in skills_list:
#         pattern = r"\b{}\b".format(re.escape(skill))
#         match = re.search(pattern, text, re.IGNORECASE)
#         if match:
#             skills.append(skill)

#     return skills

# if __name__ == '__main__':
#     text = extract_text_from_pdf(r"/content/45987048.pdf")

#     # List of predefined skills
#     skills_list = ['Python', 'Data Analysis', 'Machine Learning', 'Communication', 'Project Management', 'Deep Learning', 'SQL', 'Tableau']

#     extracted_skills = extract_skills_from_resume(text, skills_list)

#     if extracted_skills:
#         print("Skills:", extracted_skills)
#     else:
#         print("No skills found")
# Out:
# No skills found

# %%
# For Set of resumes in a folder
# Exctracting Education from Resume

import pdfminer
import re

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as pdf_file:
        pdf_reader = PdfReader(pdf_file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def extract_education_from_resume(text):
    education = []

    # Use regex pattern to find education information
    pattern = r"(?i)(?:(?:Bachelor|B\.S\.|B\.A\.|Master|M\.S\.|M\.A\.|Ph\.D\.)\s(?:[A-Za-z]+\s)*[A-Za-z]+)"
    matches = re.findall(pattern, text)
    for match in matches:
        education.append(match.strip())

    return education

if __name__ == '__main__':
    pdf_folder = "/content/drive/MyDrive/Hackathon_Dataset/Resumes_pdf"
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            text = extract_text_from_pdf(pdf_path)
            extracted_education = extract_education_from_resume(text)
        if extracted_education:
            print("Education:", extracted_education)
        else:
            print("No education information found")
# Out:
# No education information found
# Education: ['master and product owner', 'master for multiple concurrent scrum teams', 'master for multiple scrum teams in\nadditional to fulfilling my job responsibilities Managed and put process in place to ensure the off shore development center become seamless\nextension of our development team', 'Master of Science', 'Bachelor of Science']
# No education information found
# Education: ['Master Planned Developments']
# No education information found
# No education information found
# No education information found
# Education: ['Bachelor of Science']
# Education: ['Bachelor of Arts']
# Education: ['Bachelor of Science']

# %%
# # For single Resume
# # Exctracting Education

# def extract_text_from_pdf(pdf_path):
#     return extract_text(pdf_path)

# def extract_education_from_resume(text):
#     education = []

#     # Use regex pattern to find education information
#     pattern = r"(?i)(?:(?:Bachelor|B\.S\.|B\.A\.|Master|M\.S\.|M\.A\.|Ph\.D\.)\s(?:[A-Za-z]+\s)*[A-Za-z]+)"
#     matches = re.findall(pattern, text)
#     for match in matches:
#         education.append(match.strip())

#     return education

# if __name__ == '__main__':
#     text = extract_text_from_pdf(r"/content/45987048.pdf")

#     extracted_education = extract_education_from_resume(text)
#     if extracted_education:
#         print("Education:", extracted_education)
#     else:
#         print("No education information found")
# Out:
# Education: ['Bachelor of Science']

# %%
# For Set of resumes in a folder

import pdfminer
import re

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as pdf_file:
        pdf_reader = PdfReader(pdf_file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def extract_data_science_education(text):
    doc = nlp(text)

    education = []

    for ent in doc.ents:
        if ent.label_ == 'ORG' and 'Data Science' in ent.text:
            education.append(ent.text)

    return education

if __name__ == '__main__':
    pdf_folder = "/content/drive/MyDrive/Hackathon_Dataset/Resumes_pdf"
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            text = extract_text_from_pdf(pdf_path)
            extracted_education = extract_data_science_education(text)
        if extracted_education:
            print("Data Science Education:", extracted_education)
        else:
            print("No data science education found")

# %%
# # For single Resume
# import spacy

# nlp = spacy.load('en_core_web_sm')

# def extract_data_science_education(text):
#     doc = nlp(text)

#     education = []

#     for ent in doc.ents:
#         if ent.label_ == 'ORG' and 'Data Science' in ent.text:
#             education.append(ent.text)

#     return education

# if __name__ == '__main__':
#     text = extract_text_from_pdf(r"/content/45987048.pdf")

#     extracted_education = extract_data_science_education(text)
#     if extracted_education:
#         print("Data Science Education:", extracted_education)
#     else:
#         print("No data science education found")
# Out:
# No data science education found

# %%
# For Set of resumes in a folder

import pdfminer
import re

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as pdf_file:
        pdf_reader = PdfReader(pdf_file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def extract_college_name(text):
    lines = text.split('\n')
    college_pattern = r"(?i).*college.*|(?i).*university.*"
    for line in lines:
        if re.match(college_pattern, line):
            return line.strip()
    return None

if __name__ == '__main__':
    pdf_folder = "/content/drive/MyDrive/Hackathon_Dataset/Resumes_pdf"
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            text = extract_text_from_pdf(pdf_path)
            college_name = extract_college_name(text)
        if college_name:
            print("College / University:", college_name)
        else:
            print("College name not found.")
# Out:
# College / University: University of South Florida
# College / University: Webster University
# College / University: Central Piedmont College
# College / University: Charter College
# College name not found.
# College / University: Chattahoochee Technical College
# College / University: Maysville Community Technical College
# College / University: Outreach & Engagement activities of Oregon State University.
# College / University: The College of Saint Scholastica
# College / University: Albany State University

# %%
# # For single Resume
# def extract_college_name(text):
#     lines = text.split('\n')
#     college_pattern = r"(?i).*college.*|(?i).*university.*"
#     for line in lines:
#         if re.match(college_pattern, line):
#             return line.strip()
#     return None

# # Example usage:
#     text = extract_text_from_pdf(r"/content/45987048.pdf")


# college_name = extract_college_name(text)
# if college_name:
#     print("College / University:", college_name)
# else:
#     print("College name not found.")
# Out:
# College: Albany State University | City , State | 05/1986 Bachelor of Science : Psychology
# <ipython-input-13-0a76469dbac3>:5: DeprecationWarning: Flags not at the start of the expression '(?i).*college.*|(?i)' (truncated) but at position 16
#   if re.match(college_pattern, line):

# %%
# For Set of resumes in a folder

import pdfminer
import re

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as pdf_file:
        pdf_reader = PdfReader(pdf_file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def extract_contact_number_from_resume(text):
    contact_number = None

    # Use regex pattern to find a potential contact number
    pattern = r"\b(?:\+?\d{1,3}[-.\s]?)?\(?\d{3}\)?[-.\s]?\d{3}[-.\s]?\d{4}\b"
    match = re.search(pattern, text)
    if match:
        contact_number = match.group()

    return contact_number

def extract_email_from_resume(text):
    email = None

    # Use regex pattern to find a potential email address
    pattern = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
    match = re.search(pattern, text)
    if match:
        email = match.group()

    return email

def extract_skills_from_resume(text, skills_list):
    skills = []

    for skill in skills_list:
        pattern = r"\b{}\b".format(re.escape(skill))
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            skills.append(skill)

    return skills

def extract_education_from_resume(text):
    education = []

    # Use regex pattern to find education information
    pattern = r"(?i)(?:Bsc|\bB\.\w+|\bM\.\w+|\bPh\.D\.\w+|\bBachelor(?:'s)?|\bMaster(?:'s)?|\bPh\.D)\s(?:\w+\s)*\w+"
    matches = re.findall(pattern, text)
    for match in matches:
        education.append(match.strip())

    return education

def extract_name(resume_text):
    nlp = spacy.load('en_core_web_sm')
    matcher = Matcher(nlp.vocab)

    # Define name patterns
    patterns = [
        [{'POS': 'PROPN'}, {'POS': 'PROPN'}],  # First name and Last name
        [{'POS': 'PROPN'}, {'POS': 'PROPN'}, {'POS': 'PROPN'}],  # First name, Middle name, and Last name
        [{'POS': 'PROPN'}, {'POS': 'PROPN'}, {'POS': 'PROPN'}, {'POS': 'PROPN'}]  # First name, Middle name, Middle name, and Last name
        # Add more patterns as needed
    ]
    for pattern in patterns:
        matcher.add('NAME', patterns=[pattern])

    doc = nlp(resume_text)
    matches = matcher(doc)

    for match_id, start, end in matches:
        span = doc[start:end]
        return span.text

    return None

if __name__ == '__main__':
    pdf_folder = "/content/drive/MyDrive/Hackathon_Dataset/Resumes_pdf"
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            text = extract_text_from_pdf(pdf_path)
            # print("Resume:", resume_path)

            name = extract_name(text)
            if name:
                print("Name:", name)
            else:
                print("Name not found")

            contact_number = extract_contact_number_from_resume(text)
            if contact_number:
                print("Contact Number:", contact_number)
            else:
                print("Contact Number not found")

            email = extract_email_from_resume(text)
            if email:
                print("Email:", email)
            else:
                print("Email not found")

            skills_list = ['Python', 'Data Analysis', 'Machine Learning', 'Communication', 'Project Management', 'Deep Learning', 'SQL', 'Tableau']
            extracted_skills = extract_skills_from_resume(text, skills_list)
            if extracted_skills:
                print("Skills:", extracted_skills)
            else:
                print("No skills found")

            extracted_education = extract_education_from_resume(text)
            if extracted_education:
                print("Education:", extracted_education)
            else:
                print("No education information found")

            print()
# Out:
# Name: Engineering Technician
# Contact Number not found
# Email not found
# Skills: ['Communication', 'Project Management']
# No education information found
#
# Name: Career Overview
# Contact Number not found
# Email not found
# No skills found
# Education: ['master and product owner', 'master for multiple concurrent scrum teams', 'master for multiple scrum teams in\nadditional to fulfilling my job responsibilities Managed and put process in place to ensure the off shore development center become seamless\nextension of our development team', 'Master of Science', 'Bachelor of Science']
#
# Name: Company Name
# Contact Number not found
# Email not found
# Skills: ['Communication']
# No education information found
#
# Name: ENGINEERING PROJECT
# Contact Number not found
# Email not found
# Skills: ['Communication']
# Education: ['Master Planned Developments']
#
# Name: ENGINEERING AIDE
# Contact Number not found
# Email not found
# No skills found
# No education information found
#
# ...

# %%
# # For single Resume
# import re
# from pdfminer.high_level import extract_text
# import spacy
# from spacy.matcher import Matcher

# def extract_text_from_pdf(pdf_path):
#     return extract_text(pdf_path)

# def extract_contact_number_from_resume(text):
#     contact_number = None

#     # Use regex pattern to find a potential contact number
#     pattern = r"\b(?:\+?\d{1,3}[-.\s]?)?\(?\d{3}\)?[-.\s]?\d{3}[-.\s]?\d{4}\b"
#     match = re.search(pattern, text)
#     if match:
#         contact_number = match.group()

#     return contact_number

# def extract_email_from_resume(text):
#     email = None

#     # Use regex pattern to find a potential email address
#     pattern = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
#     match = re.search(pattern, text)
#     if match:
#         email = match.group()

#     return email

# def extract_skills_from_resume(text, skills_list):
#     skills = []

#     for skill in skills_list:
#         pattern = r"\b{}\b".format(re.escape(skill))
#         match = re.search(pattern, text, re.IGNORECASE)
#         if match:
#             skills.append(skill)

#     return skills

# def extract_education_from_resume(text):
#     education = []

#     # Use regex pattern to find education information
#     pattern = r"(?i)(?:Bsc|\bB\.\w+|\bM\.\w+|\bPh\.D\.\w+|\bBachelor(?:'s)?|\bMaster(?:'s)?|\bPh\.D)\s(?:\w+\s)*\w+"
#     matches = re.findall(pattern, text)
#     for match in matches:
#         education.append(match.strip())

#     return education

# def extract_name(resume_text):
#     nlp = spacy.load('en_core_web_sm')
#     matcher = Matcher(nlp.vocab)

#     # Define name patterns
#     patterns = [
#         [{'POS': 'PROPN'}, {'POS': 'PROPN'}],  # First name and Last name
#         [{'POS': 'PROPN'}, {'POS': 'PROPN'}, {'POS': 'PROPN'}],  # First name, Middle name, and Last name
#         [{'POS': 'PROPN'}, {'POS': 'PROPN'}, {'POS': 'PROPN'}, {'POS': 'PROPN'}]  # First name, Middle name, Middle name, and Last name
#         # Add more patterns as needed
#     ]

#     for pattern in patterns:
#         matcher.add('NAME', patterns=[pattern])

#     doc = nlp(resume_text)
#     matches = matcher(doc)

#     for match_id, start, end in matches:
#         span = doc[start:end]
#         return span.text

#     return None

# if __name__ == '__main__':
#     resume_paths = [r"/content/45987048.pdf"]

#     for resume_path in resume_paths:
#         text = extract_text_from_pdf(resume_path)

#         print("Resume:", resume_path)

#         name = extract_name(text)
#         if name:
#             print("Name:", name)
#         else:
#             print("Name not found")

#         contact_number = extract_contact_number_from_resume(text)
#         if contact_number:
#             print("Contact Number:", contact_number)
#         else:
#             print("Contact Number not found")

#         email = extract_email_from_resume(text)
#         if email:
#             print("Email:", email)
#         else:
#             print("Email not found")

#         skills_list = ['Python', 'Data Analysis', 'Machine Learning', 'Communication', 'Project Management', 'Deep Learning', 'SQL', 'Tableau']
#         extracted_skills = extract_skills_from_resume(text, skills_list)
#         if extracted_skills:
#             print("Skills:", extracted_skills)
#         else:
#             print("No skills found")

#         extracted_education = extract_education_from_resume(text)
#         if extracted_education:
#             print("Education:", extracted_education)
#         else:
#             print("No education information found")

#         print()
# Out:
# Resume: /content/45987048.pdf
# Name: Marilyn Hunter
# Contact Number not found
# Email not found
# No skills found
# Education: ['Bachelor of Science']

# %%
# # For single Resume

# import json
# from PyPDF2 import PdfReader
# from nltk.tokenize import word_tokenize
# from nltk.corpus import stopwords
# import nltk

# nltk.download('punkt')
# nltk.download('stopwords')

# def preprocess_text(text):
#     tokens = word_tokenize(text)
#     words = [word.lower() for word in tokens if word.isalnum()]
#     stop_words = set(stopwords.words('english'))
#     filtered_words = [word for word in words if word not in stop_words]
#     return filtered_words

# def match_keywords(text, keywords):
#     preprocessed_text = preprocess_text(text)
#     matching_keywords = [keyword for keyword in keywords if keyword in preprocessed_text]
#     return matching_keywords

# def main():
#     # Read job description JSON file
#     with open('/content/JobDescription-job_desc_front_end_engineer.pdf2f771d80-57c9-4af0-bfda-03ccd38f5970.json', 'r') as job_file:
#         job_data = json.load(job_file)
#         job_description = job_data.get('description', '')

#     # Read resume PDF file
#     with open('/content/35651876.pdf', 'rb') as resume_file:
#         pdf_reader = PdfReader(resume_file)
#         resume_content = '\n'.join(page.extract_text() for page in pdf_reader.pages)

#     # Define keywords or skills
#     keywords = ['python', 'machine learning', 'data analysis', 'communication']

#     # Match keywords in job description and resume
#     job_matches = match_keywords(job_description, keywords)
#     resume_matches = match_keywords(resume_content, keywords)

#     print("Job Description Matches:", job_matches)
#     print("Resume Matches:", resume_matches)

# if __name__ == "__main__":
#     main()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Job Description Matches: []
# Resume Matches: ['communication']

# %%
# For Multiple Resume in the folder

import json
from PyPDF2 import PdfReader
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    tokens = word_tokenize(text)
    words = [word.lower() for word in tokens if word.isalnum()]
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word not in stop_words]
    return filtered_words

def match_keywords(text, keywords):
    preprocessed_text = preprocess_text(text)
    matching_keywords = [keyword for keyword in keywords if keyword in preprocessed_text]
    return matching_keywords

def main():

    # Define keywords or skills
    keywords = ['python', 'machine learning', 'data analysis', 'communication']

    # Read job description JSON file
    with open('/content/JobDescription-job_desc_front_end_engineer.pdf2f771d80-57c9-4af0-bfda-03ccd38f5970.json', 'r') as job_file:
        job_data = json.load(job_file)
        job_description = job_data.get('description', '')

    # Read resume PDF file
    # with open('/content/35651876.pdf', 'rb') as resume_file:
    #     pdf_reader = PdfReader(resume_file)
    #     resume_content = '\n'.join(page.extract_text() for page in pdf_reader.pages)

    def extract_text_from_pdf(pdf_path):
        text = ""
        with open(pdf_path, "rb") as pdf_file:
            pdf_reader = PdfReader(pdf_file)
            for page in pdf_reader.pages:
                text += page.extract_text()
        return text

    pdf_folder = "/content/drive/MyDrive/Hackathon_Dataset/Resumes_pdf"
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            resume_content = extract_text_from_pdf(pdf_path)

        # Match keywords in job description and resume
        job_matches = match_keywords(job_description, keywords)
        resume_matches = match_keywords(resume_content, keywords)

        print("Job Description Matches:", job_matches)
        print("Resume Matches:", resume_matches)

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Job Description Matches: []
# Resume Matches: ['communication']
# Job Description Matches: []
# Resume Matches: []
# Job Description Matches: []
# Resume Matches: ['communication']
# Job Description Matches: []
# Resume Matches: ['communication']
# Job Description Matches: []
# Resume Matches: []
# Job Description Matches: []
# Resume Matches: ['communication']
# Job Description Matches: []
# Resume Matches: ['communication']
# Job Description Matches: []
# Resume Matches: ['communication']
# Job Description Matches: []
# Resume Matches: ['communication']
# Job Description Matches: []
# Resume Matches: []
